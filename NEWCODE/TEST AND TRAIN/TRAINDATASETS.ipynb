# %%
import duckdb
from pyarrow.parquet import ParquetFile

NoisyUsers1PQ="X:/PolymarketData/ByCats/NoisyUsers/NewNoisyUsers_part1.parquet"
ParquetFile(NoisyUsers1PQ).schema
# Out:
# ...
# required group field_id=-1 duckdb_schema {
#   optional int64 field_id=-1 timestamp (Int(bitWidth=64, isSigned=false));
#   optional int64 field_id=-1 block_number (Int(bitWidth=64, isSigned=false));
#   optional binary field_id=-1 transaction_hash (String);
#   optional int32 field_id=-1 log_index (Int(bitWidth=32, isSigned=false));
#   optional binary field_id=-1 address (String);
#   optional binary field_id=-1 role (String);
#   optional binary field_id=-1 direction (String);
#   optional double field_id=-1 usd_amount;
#   optional double field_id=-1 token_amount;
#   optional double field_id=-1 price;
#   optional binary field_id=-1 market_id (String);
#   optional binary field_id=-1 condition_id (String);
#   optional binary field_id=-1 event_id (String);
#   optional binary field_id=-1 nonusdc_side (String);
#   optional boolean field_id=-1 won;
#   optional int64 field_id=-1 cum_trades (Int(bitWidth=64, isSigned=true));
#   optional double field_id=-1 cum_spent_prior;
# ...

# %%
count = duckdb.query(f"SELECT COUNT(*) FROM '{NoisyUsers1PQ}'")
print(count)
# Out:
# ┌────────────┬──────────────┬──────────────────────────────────────────────────────────────────┬───────────┬────────────────────────────────────────────┬─────────┬───────────┬────────────┬──────────────┬────────┬───────────┬────────────────────────────────────────────────────────────────────┬──────────┬──────────────┬─────────┬────────────┬─────────────────┬───────────────┬───────────────────┬──────────────────┬────────────┬─────────────────┬───────────────────────┐
# │ timestamp  │ block_number │                         transaction_hash                         │ log_index │                  address                   │  role   │ direction │ usd_amount │ token_amount │ price  │ market_id │                            condition_id                            │ event_id │ nonusdc_side │   won   │ cum_trades │ cum_spent_prior │ cum_max_spent │ highest_price_yet │ lowest_price_yet │ prior_wins │ cum_price_prior │ time_since_last_trade │
# ...
